# %%
import requests
import pandas as pd
pd.set_option('future.no_silent_downcasting', True)
import numpy as np
import json 
from pprint import pprint
import os.path
import seaborn as sns
import matplotlib.pyplot as plt

# %%
region_code='Bret'
fname = f'dpe_{region_code}.csv'

region = ['22','29','35','56']

df_region = pd.DataFrame(data=None, index=None, columns=None, dtype=None, copy=None)

for i in range(len(region)):
    file = f'DPE_dep_{region[i]}.csv'
    df=pd.read_csv(file)
    print(len(df))
    df_region= pd.concat([df_region,df], ignore_index=True)
# Out:
# C:\Users\lilym\AppData\Local\Temp\ipykernel_13816\3698540581.py:10: DtypeWarning: Columns (47,75,156,182,183,213) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(file)
# 94000
# C:\Users\lilym\AppData\Local\Temp\ipykernel_13816\3698540581.py:10: DtypeWarning: Columns (149,153,179,187) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(file)
# 157000
# C:\Users\lilym\AppData\Local\Temp\ipykernel_13816\3698540581.py:10: DtypeWarning: Columns (56,87,197) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(file)
# 205000
# C:\Users\lilym\AppData\Local\Temp\ipykernel_13816\3698540581.py:10: DtypeWarning: Columns (60,94,205,215) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(file)
# 143000

# %%
df_region.to_csv(fname,index=False)

# %%
df_region
# Out:
#                   configuration_installation_chauffage_n1  \
# 0                        Installation de chauffage simple
# 1                        Installation de chauffage simple
# 2                        Installation de chauffage simple
# 3                        Installation de chauffage simple
# 4                        Installation de chauffage simple
# ...                                                   ...
# 598995  Installation de chauffage avec insert ou poêle...
# 598996  Installation de chauffage avec en appoint un i...
# 598997  Installation de chauffage avec insert ou poêle...
# 598998                   Installation de chauffage simple
# 598999                   Installation de chauffage simple
#
#         conso_chauffage_installation_chauffage_n1  \
# 0                                         13955.1
# 1                                          7563.0
# 2                                          3781.9
# 3                                          5251.1
# 4                                          4390.3
# ...                                           ...
# 598995                                    10881.7
# 598996                                     5595.0
# 598997                                    11528.2
# 598998                                     2221.3
# 598999                                     1205.2
#
#                                 type_generateur_n1_ecs_n1 numero_voie_ban  \
# 0       Ballon électrique à accumulation vertical Autr...               8
# 1       Ballon électrique à accumulation vertical Caté...           28bis
# 2       Ballon électrique à accumulation vertical Caté...              17
# 3                  Chaudière gaz à condensation 2001-2015               4
# 4       Ballon électrique à accumulation vertical Autr...              40
# ...                                                   ...             ...
# 598995  Ballon électrique à accumulation vertical Caté...             NaN
# 598996  Ballon électrique à accumulation vertical Caté...              10
# 598997  Ballon électrique à accumulation vertical Caté...              11
# 598998  Ballon électrique à accumulation vertical Autr...              30
# 598999  Ballon électrique à accumulation vertical Autr...              11
#
#         score_ban  conso_auxiliaires_ep  deperditions_murs  cout_eclairage  \
# 0            0.86                   0.0              158.0            17.0
# 1            0.53                1007.4               42.0            23.7
# 2            0.57                1240.3               86.3            33.4
# 3            0.60                1507.4              885.6            59.1
# 4            0.64                 367.0               36.2             7.8
# ...           ...                   ...                ...             ...
# 598995       0.45                1309.6               64.8            57.4
# 598996       0.48                 249.7               36.8            41.6
# 598997       0.41                1309.6               47.3            58.3
# 598998       0.55                 458.8               12.4            23.0
# 598999       0.69                7661.5              158.3           236.9
#
#         conso_auxiliaires_ef                  statut_geocodage  ...  \
# 0                        0.0  adresse géocodée ban à l'adresse  ...
# 1                      438.0  adresse géocodée ban à l'adresse  ...
# 2                      539.3  adresse géocodée ban à l'adresse  ...
# 3                      793.4  adresse géocodée ban à l'adresse  ...
# 4                      159.6  adresse géocodée ban à l'adresse  ...
# ...                      ...                               ...  ...
# 598995                 569.4  adresse géocodée ban à l'adresse  ...
# 598996                 131.4  adresse géocodée ban à l'adresse  ...
# 598997                 569.4  adresse géocodée ban à l'adresse  ...
# 598998                 199.5  adresse géocodée ban à l'adresse  ...
# 598999                3331.1  adresse géocodée ban à l'adresse  ...
#
#         production_ecs_solaire_installation_n1  facteur_couverture_solaire_n1  \
# 0                                          NaN                            NaN
# 1                                          NaN                            NaN
# 2                                          NaN                            NaN
# 3                                          NaN                            NaN
# 4                                          NaN                            NaN
# ...                                        ...                            ...
# 598995                                     NaN                            NaN
# 598996                                     NaN                            NaN
# 598997                                     NaN                            NaN
# 598998                                     NaN                            NaN
# 598999                                     NaN                            NaN
#
#         electricite_pv_autoconsommee numero_immatriculation_copropriete  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
# ...                              ...                                ...
# 598995                           NaN                                NaN
# 598996                           NaN                                NaN
# 598997                           NaN                                NaN
# 598998                           NaN                                NaN
# 598999                           NaN                                NaN
#
#         surface_tertiaire_immeuble  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 598995                         NaN
# 598996                         NaN
# 598997                         NaN
# 598998                         NaN
# 598999                         NaN
#
#         facteur_couverture_solaire_installation_chauffage_n1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 598995                                                NaN
# 598996                                                NaN
# 598997                                                NaN
# 598998                                                NaN
# 598999                                                NaN
#
#        facteur_couverture_solaire_installation_chauffage_n2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 598995                                                NaN
# 598996                                                NaN
# 598997                                                NaN
# 598998                                                NaN
# 598999                                                NaN
#
#        facteur_couverture_solaire_saisi_installation_chauffage_n1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 598995                                                NaN
# 598996                                                NaN
# 598997                                                NaN
# 598998                                                NaN
# 598999                                                NaN
#
#         facteur_couverture_solaire_saisi_n1  numero_rpls_logement
# 0                                       NaN                   NaN
# 1                                       NaN                   NaN
# 2                                       NaN                   NaN
# 3                                       NaN                   NaN
# 4                                       NaN                   NaN
# ...                                     ...                   ...
# 598995                                  NaN                   NaN
# 598996                                  NaN                   NaN
# 598997                                  NaN                   NaN
# 598998                                  NaN                   NaN
# 598999                                  NaN                   NaN
#
# [599000 rows x 220 columns]
